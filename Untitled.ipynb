# %%
# !pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in /Users/christiannogueras/opt/anaconda3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/christiannogueras/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/christiannogueras/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/christiannogueras/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /Users/christiannogueras/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
print('hello world')

####### Pre processing ######
df = pd.read_csv('Webull_Orders_Records-copy.csv')
df.set_index('Symbol', inplace=True)
df.sort_values(['Name', 'Side'], inplace=True)
# Filter cancelled orders
df = df[df['Filled'] > 0]
# df = df[df['Symbol'] == 'NNDM']
# df = df[df['Side'] == 'Sell']
df.drop(['Status', 'Filled', 'Avg Price', 'Time-in-Force',
        'Placed Time'], axis=1, inplace=True)

# remove @ on the price column and convert to numeric
df['Price'] = pd.to_numeric(df['Price'].str[1:], errors='raise')
df['Filled Time'] = pd.to_datetime(df['Filled Time'], errors='raise')

# put total
df['Total Price'] = df['Total Qty'] * df['Price']
df.to_csv('web2.csv')

######### doing analysis on data #########
currency = "${:,.2f}".format(df['Total Price'].sum())
print(currency)

buys = df[df['Side'] == 'Buy']
sells = df[df['Side'] == 'Sell']

print('buy')
print(buys.describe(include=['object']))

print('sell')
print(sells.describe(include=['object']))

# ######### Streamlit  ###########
# st.dataframe(df)
# Out:
# hello world
# $42,295.80
# buy
#                   Name Side
# count              299  299
# unique              78    1
# top     Nano Dimension  Buy
# freq                38  299
# sell
#                Name  Side
# count           200   200
# unique           80     1
# top     fuboTV Inc.  Sell
# freq             17   200
# /Users/christiannogueras/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# /Users/christiannogueras/opt/anaconda3/lib/python3.9/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "

# %%
df.tail(5)
# Out:
#                Name  Side  Total Qty  Price         Filled Time  Total Price
# Symbol
# FUBO    fuboTV Inc.  Sell        1.0   9.97 2021-01-05 10:43:40         9.97
# FUBO    fuboTV Inc.  Sell        1.0   9.74 2021-01-05 10:41:12         9.74
# FUBO    fuboTV Inc.  Sell        1.0   3.80 2020-12-23 09:49:00         3.80
# FUBO    fuboTV Inc.  Sell        4.0   9.00 2020-12-21 11:47:19        36.00
# FUBO    fuboTV Inc.  Sell        1.0  27.41 2020-11-24 09:33:54        27.41

# %%
buys
# Out:
#                  Name Side  Total Qty  Price         Filled Time  Total Price
# Symbol
# AMC     AMC Ent Holdg  Buy        1.0  56.60 2021-06-15 06:32:11        56.60
# AMC     AMC Ent Holdg  Buy        3.0  56.00 2021-06-16 09:30:07       168.00
# AMC     AMC Ent Holdg  Buy        4.0  50.28 2021-06-09 14:59:17       201.12
# AMC     AMC Ent Holdg  Buy        2.0  56.95 2021-06-03 14:51:09       113.90
# AMC     AMC Ent Holdg  Buy        1.0  37.69 2021-06-02 09:30:13        37.69
# ...               ...  ...        ...    ...                 ...          ...
# FUBO      fuboTV Inc.  Buy       17.0  31.80 2021-01-20 09:34:37       540.60
# FUBO      fuboTV Inc.  Buy        2.0  24.33 2021-01-04 14:34:33        48.66
# FUBO      fuboTV Inc.  Buy        4.0  30.00 2020-12-01 16:36:25       120.00
# FUBO      fuboTV Inc.  Buy        1.0   6.83 2020-11-27 12:54:00         6.83
# FUBO      fuboTV Inc.  Buy        1.0  21.40 2020-11-19 08:09:08        21.40
#
# [299 rows x 6 columns]

# %%
sells
# Out:
#                  Name  Side  Total Qty  Price         Filled Time  Total Price
# Symbol
# AGI       ALAMOS GOLD  Sell        1.0   0.02 2020-12-10 11:47:32         0.02
# AMC     AMC Ent Holdg  Sell        4.0  54.88 2021-06-16 09:46:46       219.52
# AMC     AMC Ent Holdg  Sell        4.0  40.00 2021-06-10 12:14:17       160.00
# AMC     AMC Ent Holdg  Sell        2.0  48.75 2021-06-04 09:30:03        97.50
# AMC     AMC Ent Holdg  Sell        1.0  60.27 2021-06-02 12:26:05        60.27
# ...               ...   ...        ...    ...                 ...          ...
# FUBO      fuboTV Inc.  Sell        1.0   9.97 2021-01-05 10:43:40         9.97
# FUBO      fuboTV Inc.  Sell        1.0   9.74 2021-01-05 10:41:12         9.74
# FUBO      fuboTV Inc.  Sell        1.0   3.80 2020-12-23 09:49:00         3.80
# FUBO      fuboTV Inc.  Sell        4.0   9.00 2020-12-21 11:47:19        36.00
# FUBO      fuboTV Inc.  Sell        1.0  27.41 2020-11-24 09:33:54        27.41
#
# [200 rows x 6 columns]

# %%
buys.plot(x='Price', y='Total Qty', kind='scatter')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Total Qty'>

# %%
sells.plot(x='Price', y='Total Qty', kind='scatter')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Total Qty'>

# %% [markdown]
# ## Profit on a stock

# %%
stockSymbol = 'NIO'
buysDF = buys.loc[stockSymbol]

# %%
totalBuys = buysDf['Total Price'].sum()
totalBuys

# %%
sellsDf = sells.loc[stockSymbol]
totalSells = sellsDf['Total Price'].sum()
totalSells
# Out:
# 3311.3300000000004

# %%
profit = totalBuys - totalSells
profit
# Out:
# -915.2199999999998

# %% [markdown]
# ## Plot

# %%
buysDF
# Out:
#             Name Side  Total Qty  Price         Filled Time  Total Price
# Symbol
